# %% [markdown]
# <a href="https://colab.research.google.com/github/jonh-rdz/DataEngineering_Clase2/blob/main/clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # clase2

# %%
print("Calculadora Python")
print("Operaciones disponibles: +, -, *, /")

# 1. Pedir operación
operacion = input("Elige una operación (+, -, *, /): ")
num1 = float(input("Ingresa el primer número: "))
num2 = float(input("Ingresa el segundo número: "))

# 2. Opciones Tipo de operaciones
match operacion:
    case '+':
        resultado = num1 + num2
        print(f"Resultado: {num1} + {num2} = {resultado}")
    case '-':
        resultado = num1 - num2
        print(f"Resultado: {num1} - {num2} = {resultado}")
    case '*':
        resultado = num1 * num2
        print(f"Resultado: {num1} * {num2} = {resultado}")
    case '/':
        if num2 == 0:
            print("Error: No se puede dividir entre cero.")
        else:
            resultado = num1 / num2
            print(f"Resultado: {num1} / {num2} = {resultado}")
    case _:
        print("Error: Operación no válida. Por favor elige +, -, * o /.")
